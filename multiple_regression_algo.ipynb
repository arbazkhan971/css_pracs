# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd

# %%
X=[]
Y=[]
"""

for line in open("data_2d.csv"):
    x1,x2,y=line.split(",")
    X.append([1,float(x1),float(x2)])
    Y.append(float(y))
X=np.array(X)
Y=np.array(Y)


"""
datasets=pd.read_csv("50_Startups.csv")
X=datasets.iloc[:,:-1].values
Y=datasets.iloc[:,1].values
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],Y,)
plt.show()
w=np.linalg.solve(np.dot(X.T,X),np.dot(X.T,Y))
yhat = np.dot(X,w)
d1=Y-yhat
d2=Y-Y.mean()
r2=1-d1.dot(d1)/d2.dot(d2)
print("approximation of model",r2)
plt.plot(X,yhat)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0f0895237873> in <module>()
#      19 ax.scatter(X[:,0],X[:,1],Y,)
#      20 plt.show()
# ---> 21 w=np.linalg.solve(np.dot(X.T,X),np.dot(X.T,Y))
#      22 yhat = np.dot(X,w)
#      23 d1=Y-yhat
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
r2
# Out:
# 0.99800406124757779
