# %%
import pandas as pd
import numpy as np

# %%
df = pd.ExcelFile('db.xlsx')

# %%
db=df.to_csv("database.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-67682ef5ee9a> in <module>()
# ----> 1 db=df.to_csv("database.csv")
#
# AttributeError: 'ExcelFile' object has no attribute 'to_csv'

# %%
import pandas as pd
data_xls = pd.read_excel('db.xlsx', index_col=None)
data_xls.to_csv('database.csv', encoding='utf-8')

# %%
df=pd.read_csv("database.csv")

# %%
df
# Out:
#      Unnamed: 0  inning      batsman_name  bowler  run  match_id  \
# 0             0       1       Karn Sharma      80    0   1136561
# 1             1       1       Karn Sharma      80    0   1136561
# 2             2       1       Karn Sharma      80    0   1136561
# 3             3       1       Karn Sharma      80    4   1136561
# 4             4       1       Karn Sharma      80    1   1136561
# 5             5       1        Evin Lewis      80    0   1136561
# 6             6       1       Karn Sharma      77    0   1136561
# 7             7       1       Karn Sharma      77    0   1136561
# 8             8       1       Karn Sharma      77    2   1136561
# 9             9       1       Karn Sharma      77    0   1136561
# 10           10       1       Karn Sharma      77    0   1136561
# 11           11       1       Karn Sharma      77    0   1136561
# 12           12       1        Evin Lewis      80    0   1136561
# ...

# %%
xls = pd.read_excel('free1.xlsx', index_col=None)
xls.to_csv('free1.csv', encoding='utf-8')

# %%
free=pd.read_csv("free1.csv")

# %%
free
# Out:
#      Unnamed: 0  over  ball  batsman  bowler  wide_runs  bye_runs  \
# 0             0     0     1      NaN     NaN        NaN       NaN
# 1             1     0     2      NaN     NaN        NaN       NaN
# 2             2     0     3      NaN     NaN        NaN       NaN
# 3             3     0     4      NaN     NaN        NaN       NaN
# 4             4     0     5      NaN     NaN        NaN       NaN
# 5             5     0     6      NaN     NaN        NaN       NaN
# 6             6     1     1      NaN     NaN        NaN       NaN
# 7             7     1     2      NaN     NaN        NaN       NaN
# 8             8     1     3      NaN     NaN        NaN       NaN
# 9             9     1     4      NaN     NaN        NaN       NaN
# 10           10     1     5      NaN     NaN        NaN       NaN
# 11           11     1     6      NaN     NaN        NaN       NaN
# 12           12     2     1      NaN     NaN        NaN       NaN
# ...

# %%
main=pd.concat([df,free],axis=1)

# %%
main
# Out:
#      Unnamed: 0  inning      batsman_name  bowler  run  match_id  \
# 0             0       1       Karn Sharma      80    0   1136561
# 1             1       1       Karn Sharma      80    0   1136561
# 2             2       1       Karn Sharma      80    0   1136561
# 3             3       1       Karn Sharma      80    4   1136561
# 4             4       1       Karn Sharma      80    1   1136561
# 5             5       1        Evin Lewis      80    0   1136561
# 6             6       1       Karn Sharma      77    0   1136561
# 7             7       1       Karn Sharma      77    0   1136561
# 8             8       1       Karn Sharma      77    2   1136561
# 9             9       1       Karn Sharma      77    0   1136561
# 10           10       1       Karn Sharma      77    0   1136561
# 11           11       1       Karn Sharma      77    0   1136561
# 12           12       1        Evin Lewis      80    0   1136561
# ...

# %%
main.to_csv("main.csv")
