# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 22 18:12:17 2018

@author: arbaz
"""

arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
    

print("1.Insertion_sort \n 2.selection_sort\n")
c=int(input())
if(c==1):
    insertionsort(arr)
elif(c==2):
    selectionsort(arr)
 
def selectionsort(newarr):
    print("You selected selection sort. \n") 

    print("Before sorting the array is", newarr) 
    for i in range(0,len(newarr)-1): 
        m=i 
        for j in range(i+1,len(newarr)):
            if(newarr[j]<newarr[m]): 
                m=j 
        temp = newarr[i]
        newarr[i]=newarr[m]
        newarr[m]=temp
    print("After sorting the array is", newarr) 
def insertionsort(newarr):  
    print("You selected insertion sort. \n")
    print("Before sorting the array is", newarr) 
    print( "After sorting the array is", insertion(newarr))
def insertion(iarr):
    for i in range(1,len(iarr)):
        value = iarr[i]
        j=i-1
        while (j>=0) and (iarr[j]>value):
            iarr[j+1] = iarr[j] 
            j=j-1
            iarr[j+1] = value 
    return iarr
# Out:
# enter a numbers of elements of array2
# 2
# enter a number of array
# 1
# 2
# 1.Insertion_sort
#  2.selection_sort
#
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-30b3749e090f> in <module>()
#      18 c=int(input())
#      19 if(c==1):
# ---> 20     insertionsort(arr)
#      21 elif(c==2):
#      22     selectionsort(arr)
#
# NameError: name 'insertionsort' is not defined

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 22 18:12:17 2018

@author: arbaz
"""
import sys
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
    

 

def selectionsort(newarr):
    print("You selected selection sort. \n") 

    print("Before sorting the array is", newarr) 
    for i in range(0,len(newarr)-1): 
        m=i 
        for j in range(i+1,len(newarr)):
            if(newarr[j]<newarr[m]): 
                m=j 
        temp = newarr[i]
        newarr[i]=newarr[m]
        newarr[m]=temp
    print("After sorting the array is", newarr) 

def insertionsort(newarr):  
    print("You selected insertion sort. \n")

    print("Before sorting the array is", newarr) 
    print( "After sorting the array is", insertion(newarr))

def insertion(iarr):
    for i in range(1,len(iarr)):
        value = iarr[i]
        j=i-1
        while (j>=0) and (iarr[j]>value):
            iarr[j+1] = iarr[j] 
            j=j-1
            iarr[j+1] = value 
    return iarr
while(True):
 print("1.Insertion_sort \n 2.selection_sort\n3.exit")
 c=int(input())
 
 if(c==1):
   insertionsort(arr)
 elif(c==2):
   selectionsort(arr)
 elif(c==3):
   sys.exit()
   
   
   '''enter a numbers of elements of array5
5
enter a number of array
23
12
1
3
2
1.Insertion_sort 
 2.selection_sort
3.exit
1
You selected insertion sort. 

Before sorting the array is [23, 12, 1, 3, 2]
After sorting the array is [1, 2, 3, 12, 23]
1.Insertion_sort 
 2.selection_sort
3.exit
2
You selected selection sort. 

Before sorting the array is [1, 2, 3, 12, 23]
After sorting the array is [1, 2, 3, 12, 23]
1.Insertion_sort 
 2.selection_sort
3.exit
'''
# Out:
# enter a numbers of elements of array5
# 5
# enter a number of array
# 23
# 12
# 1
# 3
# 2
# 1.Insertion_sort
#  2.selection_sort
# 3.exit
# 1
# You selected insertion sort.
#
# Before sorting the array is [23, 12, 1, 3, 2]
# After sorting the array is [1, 2, 3, 12, 23]
# 1.Insertion_sort
#  2.selection_sort
# 3.exit
# 2
# You selected selection sort.
#
# Before sorting the array is [1, 2, 3, 12, 23]
# After sorting the array is [1, 2, 3, 12, 23]
# 1.Insertion_sort
#  2.selection_sort
# 3.exit
# 3
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\arbaz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
