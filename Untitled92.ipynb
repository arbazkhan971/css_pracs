# %%
from selenium import webdriver
from bs4 import BeautifulSoup
driver = webdriver.PhantomJS(executable_path = r'C:\Users\arbaz\Downloads\phantomjs-2.1.1-windows\phantomjs-2.1.1-windows\bin\phantomjs.exe')
url=input("enter url of match")
driver.get(url)

html_doc = driver.page_source
soup=BeautifulSoup(html_doc,'lxml')

paragraphtag=soup.find_all("p",{"cb-com-ln ng-binding ng-scope cb-col cb-col-90"})

comm=[]
for i in paragraphtag:
    comm.append(i.text)

with open ("test.txt","w")as fp:
   for line in comm:
       fp.write(line+"\n")
driver.quit()


"""

just copy and paste the url of match from cricnuzz and change the file name






"""
# Out:
# c:\users\arbaz\anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# enter url of matchhttps://www.cricbuzz.com/cricket-full-commentary/20351/wi-vs-ban-1st-odi-bangladesh-tour-of-west-indies-2018
# '\n\njust copy and paste the url of match from cricnuzz and change the file name\n\n\n\n\n\n\n'

# %%
comm
# Out:
# ['Mustafizur to Devendra Bishoo, no run, slower bouncer and the slog across the line is missed. Bangladesh win this by 48 runs! This has been a comprehensive win for the visitors after being ridiculed in the Tests',
#  'Mustafizur to Devendra Bishoo, no run, pushed back to the bowler. Solidly done. Not the need of the hour though',
#  "Mustafizur to Devendra Bishoo, 2 runs, another overthrow and they get an extra run. That was dragged away to mid-off, who aimed a direct hit at the bowler's end and missed to allow the extra run",
#  'Mustafizur to Devendra Bishoo, no run, goes for the reverse paddle and does not get it anywhere as he was cramped with the line and the length. Might have got some bat on it as it scooped up to land in the proximity of the sticks',
#  'Mustafizur to Devendra Bishoo, no run, backs away and yorks the ball out into the 22 yards',
#  'Mustafizur to Alzarri Joseph, 1 run, low full delivery outside off and has been toe-ended into the off-side',
#  'Rubel to Devendra Bishoo, FOUR, short ball and punished. The batsman cleared his feet and tonked the pull away. There was no one at the deep mid fence',
#  'Rubel to Devendra Bishoo, no run, short ball, going across the batsman and he misses it',
#  'Rubel to Alzarri Joseph, 1 run, right up there and the batsman digs the ball out to long-on',
#  'Rubel to Devendra Bishoo, 1 run, shortish ball and has been pulled away to deepish long-on for a single',
#  'Rubel to Devendra Bishoo, 2 runs, sky ball, high ball and it lands over the man at mid-wicket was running back. Slower delivery and the batsman went for the slog sweep to mistime it over mid-wicket',
#  'Rubel to Devendra Bishoo, FOUR, length ball and has been swiped across the line. The man at long-on got to it but then the momentum took it away. The one-handed effort was never good enough',
#  'Mustafizur to Alzarri Joseph, no run, full ball and well outside off, the batsman could never reach it only to let it go. The ball was just inside the tramline and hence was not called a wide',
#  'Mustafizur to Devendra Bishoo, 1 run, shatters the sticks at the other end as he backed away to power the ball down the ground. They steal a single',
#  'Mustafizur to Devendra Bishoo, no run, stays behind the line of the ball and pushes the ball away to cover',
#  'Mustafizur to Devendra Bishoo, no run, slower delivery and the batsman misses the tuck into the on-side',
#  'Mustafizur to Devendra Bishoo, no run, backs away and mistimes the ball away to mid-off',
#  'Mustafizur to Alzarri Joseph, 1 run, full ball and the batsman backs away to squeeze the ball out into the covers for a single',
#  'Rubel to Devendra Bishoo, no run, slower delivery and has been defended back to the bowler',
#  'Rubel to Devendra Bishoo, no run, backs away and pushes the ball out into the off-side',
#  'Rubel to Alzarri Joseph, 1 run, looks to slog it away and inside edges the ball on to the pads. The ball dribbled past the keeper for them to take a single',
#  'Rubel to Alzarri Joseph, wide, gets it horribly wrong and an excellent dive from Mushy to his left ensures there are no five runs to the tally',
#  'Rubel to Alzarri Joseph, no run, right up there and has been dug out. The inside edge takes the ball away to short fine leg',
#  'Rubel to Alzarri Joseph, FOUR, that was hit hard! Brutal hit but that should have been taken by the man at mid-off. The length ball was hammered and Mosaddek got his hands to the ball but it burst through it',
#  'Rubel to Devendra Bishoo, 1 run, backs away but then defends it into the off-side for a single',
#  'Mustafizur to Devendra Bishoo, 1 run, back of a length delivery outside off and was slower in pace. Punched into the covers for a single',
#  'Mustafizur to Devendra Bishoo, no run, the perfume ball and the batsman sways away out of the aroma and leaves it alone',
#  'Mustafizur to Devendra Bishoo, no run, short of length delivery and the batsman fails to tuck it away. Gets hit on the thigh pad',
#  'Mustafizur to Alzarri Joseph, 1 run, slogs the ball down the ground and the man at long-on mops the ball up',
#  'Mustafizur to Devendra Bishoo, 1 run, reverse sweep and it went too fine! The ball landing just short of the man at deep third. Picked the right ball but could not get the execution right',
#  'Mustafizur to Devendra Bishoo, no run, gets the ball shape away after landing and the batsman was squared up and beaten. Lovely delivery',
#  'Rubel to Alzarri Joseph, no run, slower delivery outside off and has been inside edged into the on-side',
#  'Rubel to Alzarri Joseph, FOUR, length ball and has been smacked down the ground. The bowler and the umpire take evasive action as the batsman presented the full face of the bat to muscle it down the ground',
#  'Rubel to Devendra Bishoo, 1 run, too full and has been swatted down the ground to long-on for a single',
#  'Rubel to Devendra Bishoo, no run, full ball has been blocked into the on-side',
#  'Rubel to Devendra Bishoo, no run, bangs the ball in, the batsman goes across his sticks and ducks under it',
#  'Rubel to Devendra Bishoo, no run, blocks the ball back to the bowler off the back foot',
#  'Shakib to Alzarri Joseph, SIX, ballooned up delivery and Alzarri Joseph provides more helium to it. That has whizzed away over widish long-on for a sixer. The batsman got under the ball and gave it the full monty. Devendra Bishoo eked a smile out post the big hit',
#  'Shakib to Alzarri Joseph, no run, looks to knock the ball away into the on-side and the leading edge takes it into the deck',
#  'Shakib to Alzarri Joseph, byes, FOUR, lucky! Unlucky is the bowler though as that missed the sticks by a whisker. The arm ball speared in and it missed the slog across the line. The keeper missed it as well and the ball ran away into the fence',
#  'Shakib to Alzarri Joseph, SIX, swiped across the line and that has gone many a mile! That was tossed up and the batsman took the aerial route in style',
#  'Shakib to Devendra Bishoo, 1 run, nudged away into the on-side for a single',
#  'Shakib to Alzarri Joseph, 1 run, full ball has been bludgeoned down the ground to long-off',
#  'Rubel to Devendra Bishoo, no run, really full and has been clipped away to the man at mid-wicket',
#  'Rubel to Alzarri Joseph, 1 run, length ball outside off and has been punched into the covers for a single',
#  'Rubel to Alzarri Joseph, no run, slower delivery and has been swiped across the line of the ball for the man at mid-wicket to pick it up',
#  'Rubel to Alzarri Joseph, no run, looks to tonk it away and toe-ends the ball into the on-side',
#  "Rubel to Devendra Bishoo, 1 run, overthrows allow a single. The batsman backed away and sliced the ball into the covers. The man at cover picked the ball up and went for a shy at the batter's end. There was no one backing up and that allowed the extra run",
#  'Rubel to Devendra Bishoo, no run, length ball at the sticks and has been blocked to the man at cover',
#  'Shakib to Alzarri Joseph, no run, stays back and punches the ball into the off-side',
#  'Shakib to Devendra Bishoo, 1 run, slams the uppish drive to long-off for a single',
#  'Shakib to Devendra Bishoo, no run, went for the reverse and missed it. His back foot had dragged out of the crease but came back in time. The square leg umpire went upstairs to the third umpire, who had a brief look before signalling it not out',
#  'Shakib to Devendra Bishoo, no run, stays his crease and blocks the ball into the on-side',
#  'Shakib to Devendra Bishoo, no run, on the pads, clipped away to mid-wicket',
#  'Shakib to Alzarri Joseph, 1 run, goes back and tucks the ball away into the on-side for a single',
#  'Mortaza to Devendra Bishoo, FOUR, spanked down the ground. Round the wicket length ball and the batsman cleared his front foot to butcher that between the bowler and the mid-on fielder for a four. The bottom hand coming into good use. No fifer for the Bangladeshi skipper',
#  'Mortaza to Alzarri Joseph, 1 run, length ball outside off and has been pushed away into the off-side for a single',
#  'Mortaza to Nurse, out Caught by Mahmudullah!! Slower ball engulfs another one. The batsman went through with the big heave down the ground. Rather was drawn into it and the bat face turned a bit. The ball never scaled a lot of distance and the man at long-on made easy work out of that. Fourth wicket for the skipper. Leading from the front! Nurse c Mahmudullah b Mortaza 7(11)',
#  'Mortaza to Nurse, 2 runs, slower delivery angling in and has been knocked away into the on-side. There was no one in the circle and they race back for a double before the man at deep mid could cut it off',
#  'Mortaza to Devendra Bishoo, 1 run, slower delivery on the pads, worked away into the on-side for a single',
#  'Mortaza to Nurse, 1 run, slower ball for the umpteenth time and has been worked away behind square for a single',
#  'Shakib to Devendra Bishoo, no run, gets squared up and pushes the ball away into the covers',
#  'Shakib to Devendra Bishoo, 2 runs, turns the ball away off the pads into the on-side for a single. In fact they have raced back for a brace',
#  'Shakib to Nurse, 1 run, on the pads and clipped away into the on-side for a single',
#  'Shakib to Devendra Bishoo, 1 run, wristy on-drive and that finds the man at long-on for a single',
#  'Shakib to Nurse, 1 run, chips down the track and then nurdles the ball away into the on-side for a single',
#  'Shakib to Nurse, no run, pushed back to the bowler as it was arrowed in',
#  'Mortaza to Devendra Bishoo, no run, slower short ball and has been defended off the back foot',
#  'Mortaza to A Russell, out Caught by Mahmudullah!! Slower delivery and the lack of pace on the wicket gets another one. Russell knelt down and went for the slog down the ground but could only sky it high. The man at long-on got under it and took it easily. That is it for me. Safe to say Windies are going down today. Their ray of hope has also vanquished now. A Russell c Mahmudullah b Mortaza 13(12) [4s-1 6s-1]',
#  'Mortaza to A Russell, no run, nice bumper. Might have been a slower one as well with the speed gun reading 118kph. The batsman bailed out of a shot and allowed the ball to go through',
#  'Mortaza to A Russell, no run, slower delivery and the ball misses the woodwork not by much. Goes for a wild swing across the line and is beaten by the lack of pace. Another off-cutter and it fooled him',
#  'Mortaza to Nurse, 1 run, goes down on one knee and swipes the ball past the man at mid-wicket for a single',
#  'Mortaza to Nurse, no run, pacy length beats the poking blade as the batsman was trying to come down and push the ball away. The ball landed outside off and shaped away further to miss the willow',
#  'Mustafizur to A Russell, no run, looks to be cheeky by running it down towards deep third man and misses',
#  "Mustafizur to A Russell, FOUR, murdered! Down the ground and over the bowler's head. That was slanted across and was bowled pretty wide. The batsman fetched it and flat-batted it back towards the bowler. The umpire ducked down",
#  'Mustafizur to A Russell, SIX, where has that gone? Bye bye ball. Search your roof-tops folks! That flew away outta here. Length ball outside off going across the batsman and was swiped across the line without a lot of feet. Goodness! This man can hit them long! That was a 104m hit towards the longest part of the ground. New ball has arrived!',
#  'Mustafizur to Nurse, 1 run, walks across his sticks and tickles the ball away to fine leg',
#  'Mustafizur to Nurse, no run, goes across his sticks and blocks the ball out into the off-side',
#  'Mustafizur to Nurse, no run, fuller ball outside off and the batsman stretches out and drives the ball to cover',
#  'Mortaza to A Russell, no run, short one, directed at the face, A Russell thinks about playing a shot, but sways - in fact crab-walks out of the way. Evaded',
#  'Mortaza to Holder, out Caught by Mosaddek Hossain! Another length ball, off-cutter, holds up and the tackiness comes into play. Holder tries to slug it away as though it were a true-bounce pitch, but ends up half-way through a checked shot, only to chip it in the air straight down the ground for the man at mid-off to come around and settle under it runnign backwards. Ended up making it look very easy and he exults with joy. Holder c Mosaddek Hossain b Mortaza 17(18) [6s-1]',
#  "Mortaza to Holder, SIX, a tired long-hop, can't think of a better ball, Holder makes room and heaves that over long-on for six",
#  'Mortaza to A Russell, 1 run, back of a length once again, sitting up for the batsman, who clubs it cross-battedly down to wide long-on for a single',
#  'Mortaza to Holder, 1 run, back of a length delivery outside off, holding up, pulled away to deep mid-wicket for a single',
#  'Mortaza to A Russell, 1 run, short one without width, A Russell gets into a retro-cut position and taps it on the head towards third man for a single',
#  'Mustafizur to A Russell, 1 run, good length delivery shooting up, surprisingly so, and Russell is back in the crease to punch it crisply to cover for a single',
#  'Mustafizur to A Russell, no run, back of a length delivery in line wiht off-stump, A Russell gets back in his crease to defend it off the back foot under his eyes',
#  'Mustafizur to A Russell, no run, good length ball on off, Russell is well behind it with a solid punch to mid-off',
#  "Mustafizur to Powell, out Caught by Rahim! He's on a hat-trick! Short of a length, seaming away, Powell is hypnotized into chasing after that one without any feet and nicks it through to the keeper, can't believe what he has done. What a seed The Fizz has produced on his comeback! An absolute gem! Powell c Rahim b Mustafizur 0(1)",
#  "Mustafizur to Hetmyer, out Caught by Shakib! Against the run of play! Coming in sharply, pitching on a short of length, Hetmyer charges and is cramped by the inward cutter, and tries to punch it away through the covers, but fails to keep it down, ends up handing Shakib at short cover a straightforward catch. That's the one Bangladesh needed. They can smell victory. Hetmyer c Shakib b Mustafizur 52(78) [4s-5]",
#  'Mustafizur to Holder, 1 run, full and wide outside off, Holder reaches out and drives it down to long-off for a single',
#  'Mortaza to Hetmyer, no run, back of a length delivery on middle and leg, Hetmyer stays back and punches it straight-batted off the back foot to Mortaza',
#  'Mortaza to Hetmyer, no run, shorter one angling away, stays low, and does down to the keeper, crossing the batsman miles beneath the attempted pull',
#  'Mortaza to Hetmyer, no run, good length delivery angling across, served up outside off, carved away towards point off a low stance',
#  'Mortaza to Holder, leg byes, 1 run, length ball going down leg, Holder misses the glance, loud appeal, but certainly down leg. It deflects off the pads into the off-side, and they steal a leg-bye',
#  'Mortaza to Holder, no run, length ball on off, Holder gets forward, makes room, and swat-drives it with wrists running through it towards cover',
#  'Mortaza to Holder, no run, short of length delivery going straight on at the fourth stump line, Holder gets back and across and punches it to mid-off',
#  'Shakib to Hetmyer, no run, fired in flat on leg-stump, Hetmyer opens up his stance and punches it to cover off the back foot',
#  'Shakib to Holder, 1 run, closer to off, same enticing length, a lean and a push to cover for a quick single',
#  'Shakib to Holder, no run, good length ball straightening on middle and off, blocked back',
#  'Shakib to Hetmyer, 1 run, in the broom-zone from round the wicket, Hetmyer gets a top-edge to backward square leg for a single as it falls short of the fielder stationed there',
#  'Shakib to Hetmyer, no run, angling away off a length, tight line, punched back to the bowler off the back foot',
#  "Shakib to Hetmyer, 3 wides, round the wicket, turn, Holder misses the sweep, Mushy's mitts miss it too, and he cringes in agony. 3 wides",
#  'Shakib to Holder, 1 run, fuller one, tossed up, Holder reaches out and runs his hands through it to drive it down to sweeper cover for a single',
#  'Mehidy Hasan to Holder, 1 run, straying on the pads, deflected away at the last moment to in front of square leg for a single',
#  'Mehidy Hasan to Hetmyer, 1 run, a tad short, punched down to long-on for another single',
#  'Mehidy Hasan to Holder, 1 run, angling in, holds in the pitch, Holder forces the flicks, gets it in the air but not for long to square leg for a single',
#  'Mehidy Hasan to Hetmyer, 1 run, flatter and slanting in towards leg, pucnhed from deep in the crease down to long-on for a single. Fifty for Hetmyer. Lots of character and grit in that innings against some quality bowling',
#  'Mehidy Hasan to Hetmyer, no run, a tad shorter, skiddier, turning away, chopped to cover point',
#  'Mehidy Hasan to Holder, 1 run, fuller and flatter on off, Holder uses his abundant reach to get forward and swat it down to long-on for a single',
#  "Shakib to Hetmyer, no run, tossed up angling towards leg, holds its line as Hetmyer tries to turn it away with the spin that isn't there, gets a checked leading edge that doesn't carry back to the bowler",
#  'Shakib to Hetmyer, no run, full and drifting towards the pads, Hetmyer gets across into a position to sweep and paddles it to short fine leg',
#  'Shakib to Hetmyer, no run, cramped for room with the trajectory, line and length, tight on off, punched back towards the bowler',
#  'Shakib to Hetmyer, FOUR, shorter one, stays low, but slow bounce, a low stance and an almighty carve away square of the wicket for four. Full-blooded',
#  'Shakib to Hetmyer, no run, length ball fired in flat on the pads, Hetmyer turns it away delicately towards square leg',
#  'Shakib to Hetmyer, wide, down leg, Hetmyer tries to paddle it away, misses. Wide called',
#  'Shakib to Holder, 1 run, fuller and wide outside off, turning away, Holder reaches out and plays a horizontal-batted drive with the turn towards sweeper cover for a single',
#  'Mehidy Hasan to Hetmyer, no run, pulls back the length, maintains the line, Hetmyer is more compact in his punch this time, pushes it to cover once again, and fails to get it through the in-field',
#  "Mehidy Hasan to Hetmyer, no run, fuller this time, Hetmyer reaches out to smother the turn and drives it straight to short cover again. Can't pierce the gap",
#  'Mehidy Hasan to Hetmyer, no run, flat, angling in, straightening, carved off the back foot towards short cover',
#  'Mehidy Hasan to Holder, 1 run, a bit more air, Holder reaches for it down the wicket and whips it away to wide long-on for a single',
#  'Mehidy Hasan to Holder, no run, flat and length again, on middle, Holder gets back and taps it on the head, down the pitch',
#  'Mehidy Hasan to Hetmyer, 1 run, fired in on a length from round the wicket, tucked away behind square leg for a single',
#  'Shakib to Hetmyer, 1 run, skidding straight on towards middle and leg, Hetmyer gets back and taps it late with an angled bat in front of square leg for a single',
#  'Shakib to Hetmyer, FOUR, tossed up, too full, Hetmyer comes down the track and to the pitch of it, drives it full-throttle through long-off for four',
#  'Shakib to Holder, 1 run, fuller one this time, easily whipped down to long-on for a single',
#  'Shakib to Hetmyer, 1 run, a tad short again, continues to skid, tucked off the back foot to mid-wicket for a single',
#  'Shakib to Hetmyer, no run, hurrying him with the length ball on middle and leg this time, tapped to mid-wicket',
#  'Shakib to Hetmyer, no run, good length zippy delivery on off, headed for the top of the stumps, tapped late towards point',
#  'Mehidy Hasan to Hetmyer, 1 run, fuller and wider outside off, Hetmyer gets forward and leans into a well-timed drive to sweeper cover for a single',
#  'Mehidy Hasan to Hetmyer, no run, angling in, holding its line, short again, punched to short mid-wicket',
#  'Mehidy Hasan to Hetmyer, no run, shorter and skiddier, in line with the fulcrum, punched back to the bowler',
#  'Mehidy Hasan to Holder, 1 run, on the pads, turned away to mid-wicket for a single',
#  "Mehidy Hasan to Mohammed, out Caught by Rahim! Flatter one, no turn, Mohammed tries to heave it into the on-side with the non-existent turn, and the lack of turn deceives him. Takes the outside edge of the bat and into Mushy's gloves. Excellent reflexes to take that catch, and he whips off the bails as a precautionary measure. It's been given stumped. Mohammed c Rahim b Mehidy Hasan 10(19)",
#  'Mehidy Hasan to Mohammed, no run, flat off-break on a length outside off, Mohammed gets forward and defends',
#  'Shakib to Mohammed, 1 run, skiddy arm ball angling towards middle and cramping the batsman committed to the cut; he ends up chopping it off the under-edge to short third man for a single',
#  'Shakib to Mohammed, no run, angling in, straightening off the wicket towards off and middle, punched off the back foot to short cover',
#  'Shakib to Mohammed, no run, slow, loopy, on middle, driven back to the bowler',
#  'Shakib to Hetmyer, 1 run, a tad short and turning into the pads, tucked off the back foot to square leg for a single',
#  "Shakib to Hetmyer, no run, over the wicket, loopy, Hetmyer comes down the track and nails the drive down the ground only for Shaks to stick out his left foot and stop it. Dangerous, but he's not injured",
#  'Shakib to Mohammed, 1 run, the armer, tossed up and holding the line, a thick inside edge off the front foot to square leg for a single',
#  'Mehidy Hasan to Hetmyer, 2 runs, not too short and not too wide either, but it holds up in the pitch and sits up for the cut. Hetmyer obliges by crouching low and carving it square of the wicket for a brace',
#  'Mehidy Hasan to Mohammed, 1 run, hint of turn inwards from a back of a length, Mohammed punches it to cover off the back foot for a single',
#  'Mehidy Hasan to Hetmyer, 1 run, good length and straightening, a bit of overspin, Hetmyer gets back in the crease and VVSes a whip off the back foot to mid-wicket for a single',
#  'Mehidy Hasan to Hetmyer, no run, fuller length and flatter on middle, pushed back to the bowler',
#  'Mehidy Hasan to Hetmyer, no run, off-break outside off, turning away, angled-batted steer to point',
#  "Mehidy Hasan to Mohammed, 1 run, shortish, keeps low, there's width too, Hetmyer cuts it away straight to deep backward point for a single. Can't find the gap, missed opportunity",
#  'Mosaddek Hossain to Hetmyer, FOUR, going in with the arm and zipping through with less friction from a length, Hetmyer uses his wrists to create width, backs away, and carves that away off a low stance through deep backward point for four',
#  'Mosaddek Hossain to Hetmyer, no run, a tad short but skidding towards off, Hetmyer slaps it straight to cover',
#  'Mosaddek Hossain to Mohammed, 1 run, fuller and outside off, Mohammed gets forward to kill the spin and drives it away to sweeper cover for a single',
#  'Mosaddek Hossain to Hetmyer, 1 run, a tad short, not quite a half-tracker, Hetmyer manages to get back and carve it away square of the wicket for a single',
#  'Mosaddek Hossain to Hetmyer, no run, a bit more flight on middle, Hetmyer makes room, comes down the track, and pushes it to mid-off',
#  'Mosaddek Hossain to Mohammed, 1 run, angling in flattish and on the stumps, Mohammed paddles it away fine with a sweep for a single',
#  'Mustafizur to Hetmyer, no run, back of a length delivery on middle, Hetmyer hops and then realises that the bounce is dead, pokes his bat down just in time to tap it into the wicket',
#  'Mustafizur to Mohammed, 1 run, fuller length delivery once again outside off, Mohammed walks at it and steers that away off the outside half of the bat towards deep backward point for a single',
#  'Mustafizur to Hetmyer, 1 run, good length delivery skidding on outside off, Hetmyer gets low in his stance and plays a deft late-cut away towards third man for a single',
#  "Mustafizur to Hetmyer, FOUR, half-volley on the pads, Hetmyer gets slightly across towards off-stump, doesn't commit or lose balance, and runs his hands through the whip-drive through mid-on for four. No stopping that!",
#  "Mustafizur to Hetmyer, no run, length delivery and cutting in, punched back late and compactly to the bowler's right",
#  'Mustafizur to Hetmyer, 2 runs, full and wide outside off, Mohammed gets on his knee and tries to caress it through the off-side, gets a thick outside edge and gets it behind deep point for a brace',
#  'Mosaddek Hossain to Mohammed, no run, off-break and a tad short, zipping on towards middle and leg, Mohammed gets on the back foot and makes room, feels the need to play against he turn, and taps it towards short cover',
#  'Mosaddek Hossain to Mohammed, no run, very full in length, whip-driven back to the bowler',
#  'Mosaddek Hossain to Mohammed, 2 runs, off-break outside off, turning in and keeping low, Mohammed adjusts for the lack of bounce and punches it to sweeper cover for a brace',
#  'Mosaddek Hossain to Mohammed, no run, off-break once again, turned away towards mid-on',
#  'Mosaddek Hossain to Mohammed, no run, off-break on a length, Mohammed tries to turn it away and misses. Trundles into the on-side',
#  'Mosaddek Hossain to Hetmyer, 1 run, tossed up outside off, Hetmyer makes room and drives it down to long-off for a single',
#  'Mustafizur to Mohammed, no run, fuller length delivery outside off, Mohammed gets a big stride forward on the drive - pushes it back to the bowler, off the inner half of the bat',
#  'Mustafizur to Hetmyer, 1 run, on a good length and just outside off, worked wide of cover for a single',
#  'Mustafizur to Hetmyer, no run, short of a length and just outside off, steered straight to the fielder at backward point',
#  'Mustafizur to Mohammed, 1 run, on a good length and well outside off, pushed into the gap wide of cover for a single',
#  "Mustafizur to Hetmyer, 1 run, fuller length delivery on Hetmyer's pads, whipped away in front of square on the on-side for a single",
#  'Mustafizur to Hetmyer, no run, on a good length and angling back into the left-hander, tucked towards mid-wicket',
#  'Mosaddek Hossain to Mohammed, no run, tossed up on off, Mohammed gets a big stride forward and turns it towards square leg, wanted a single but is sensibly sent back',
#  'Mosaddek Hossain to Hetmyer, 1 run, fraction short and at the stumps, worked away towards long-on for a single',
#  'Mosaddek Hossain to Hetmyer, no run, tossed up on off, defended towards the on-side',
#  "Mosaddek Hossain to Hetmyer, out Gayle Run Out!! Oh dear! Gayle was batting patiently, but has now been run-out. Is this the match for Bangladesh? Lack of communication and that did the big man in, he set-off for a quick single after Hetmyer dabbed one to the right of short third man. Was there a run in it? I ain't sure, but it was Gayle's call, he was sent back way too late, Mahmudullah's throw wasn't the best, but Mosaddek had plenty of time to collect and break the stumps - with Gayle miles short of his ground. Gayle run out (Mahmudullah/Mosaddek Hossain) 40(60) [4s-1 6s-2]",
#  'Mosaddek Hossain to Hetmyer, no run, lovely ball, drifted in, drew Hetmyer forward before spinning past the outside edge. Hetmyer followed the line and nearly edged it to the keeper',
#  'Mosaddek Hossain to Gayle, 1 run, tossed up on off, Gayle gets forward and drives it to long-off for a single',
#  'Mustafizur to Hetmyer, no run, short of a length and just outside off, Hetmyer plays away from his body and stabs it towards the off-side',
#  'Mustafizur to Hetmyer, no run, Mustafizur shortens his length on off, defended back at the bowler',
#  'Mustafizur to Gayle, 1 run, short of a good length and just outside off, dabbed down towards third man for a single',
#  "Mustafizur to Hetmyer, 1 run, fuller length delivery on Hetmyer's pads, clipped away in front of square on the on-side for a single",
#  'Mustafizur to Gayle, 1 run, on a good length and just outside off, driven to the left of cover for a single',
#  "Mustafizur to Gayle, no run, full and slanting into Gayle's pads, clipped straight to the fielder at mid-wicket",
#  'Mosaddek Hossain to Hetmyer, no run, Hetmyer takes a step down the track to a well flighted delivery and then defends',
#  'Mosaddek Hossain to Hetmyer, no run, tossed up on middle and drifting across the left-hander, Hetmyer went down on his knees and is struck high on the pads',
#  'Mosaddek Hossain to Hetmyer, 2 runs, nicely tossed up outside off, Hetmyer leans forward, opens the face of the bat and runs it past the man at short third man. Sabbir gives chase and pulls the ball back in, saves a couple of runs',
#  'Mosaddek Hossain to Gayle, 1 run, tad too short and at the stumps, Gayle punches it down towards long-on for a single',
#  'Mosaddek Hossain to Gayle, no run, slower and on the stumps, defended back at the bowler',
#  'Mosaddek Hossain to Gayle, no run, flighted just outside off, pushed with soft hands towards the off-side',
#  "Rubel to Hetmyer, no run, Rubel shortens his length and drifts onto Hetmyer's pads, clipped straight to the fielder at mid-wicket",
#  'Rubel to Gayle, 1 run, full and on the stumps, pushed into the gap wide of cover-point for a single',
#  'Rubel to Hetmyer, 1 run, on a good length and just outside off, Hetmyer prods it in front of cover and calls his partner across for a quick single',
#  'Rubel to Gayle, 1 run, short of a good length and just outside off, dabbed with an angled bat towards backward point',
#  'Rubel to Hetmyer, 1 run, fuller length delivery and just outside off, worked with an open face - square on the off-side for a single',
#  'Rubel to Gayle, 1 run, on a good length and just outside off, Gayle pushes it in front of mid-off and scampers across for a quick single',
#  'Mosaddek Hossain to Gayle, 1 run, slower and just outside off, tucked wide of cover for a single',
#  'Mosaddek Hossain to Gayle, no run, Mosaddek tosses this one just outside off, pushed towards the off-side',
#  'Mosaddek Hossain to Gayle, no run, pushed through flatter and quicker, Gayle makes room and finds cover with the punch',
#  "Mosaddek Hossain to Gayle, no run, Mosaddek drifts this one on Gayle's pads, turned towards the on-side",
#  'Mosaddek Hossain to Hetmyer, 1 run, flighted delivery on the stumps, worked away towards long-on for a single',
#  'Mosaddek Hossain to Hetmyer, no run, tossed up well outside off, dabbed straight to the fielder at short third man',
#  'Rubel to Hetmyer, 1 run, on a good length and wide of off, nudged wide of cover-point for a single',
#  'Rubel to Hetmyer, no run, short of a length and on the stumps, nudged away towards the on-side',
#  'Rubel to Hetmyer, no run, Rubel shortens his length outside off, dropped towards cover-point',
#  'Rubel to Gayle, 1 run, on a good length and just outside off, Gayle pushes it in front of mid-off for a quick single',
#  'Rubel to Gayle, SIX, cracking shot, length ball outside off, Gayle leans forward and lifts it nonchalantly over mid-off, went soaring over the ropes for a maximum',
#  'Rubel to Gayle, 2 runs, short of a length and angling across the left-hander, Gayle plays with an open face and dabs it behind square on the off-side. The fielder tumbles over the ball, concedes another run',
#  'Mosaddek Hossain to Hetmyer, no run, tossed up on off, Hetmyer comes down the track and gets an inside edge onto the pads, the ball rolls away towards cover',
#  "Mosaddek Hossain to Gayle, 1 run, loud shout for LBW and Bangladesh want a review. Gayle was a long way down the track, was it sliding down the leg-side? It's a fair delivery and it's clearly pad-first, did the ball straighten enough? Umpire's call on 3m and umpire's call on hitting, Gayle will survive. Mortaza has a chat with umpire Ravi, but all ends well, Gayle was a long way down, the ball clipped the pad and then went off the bat towards long-on",
#  'Mosaddek Hossain to Hetmyer, 1 run, Hetmyer shimmies down the track to a well flighted delivery and eases it down towards long-off',
#  'Mosaddek Hossain to Hetmyer, no run, nicely flighted on off, Hetmyer gets close to the ball as he blocks',
#  'Mosaddek Hossain to Hetmyer, no run, Mosaddek tosses this one just outside off, pushed straight to the fielder at cover',
#  'Mosaddek Hossain to Hetmyer, no run, tossed up well outside off, Hetmyer leans forward and tucks it towards backward point',
#  'Rubel to Hetmyer, 1 run, on a good length and just outside off, pushed to the left of point for a single',
#  'Rubel to Hetmyer, FOUR, cracking shot, fraction short and just outside off, Hetmyer is qucik to pick the length, swivels across, rolls his wrists and pulls it in front of square on the on-side for a boundary',
#  "Rubel to Hetmyer, no run, on a good length and on Hetmyer's pads, turned away towards mid-wicket",
#  'Rubel to Gayle, 1 run, tad fuller and just outside off, driven to the right of mid-off for a quick single',
#  'Rubel to Gayle, no run, lovely bowling from Rubel, full and shaping away from the left-hander, drew Gayle into the drive and beat him on the outside edge',
#  'Rubel to Hetmyer, 1 run, short of a good length and angling across the left-hander, worked in front of mid-wicket for a quick single',
#  'Mosaddek Hossain to Hetmyer, 1 run, fraction short and at the stumps, punched down towards long-on for a single',
#  'Mosaddek Hossain to Hetmyer, no run, Mosaddek drifts this one with a flatter trajectory, defended back at the bowler',
#  'Mosaddek Hossain to Gayle, 1 run, tad too full and on the stumps, eased down towards long-on for a single',
#  'Mosaddek Hossain to Gayle, no run, slower and on the leg-stump line, defended towards the bowler',
#  'Mosaddek Hossain to Gayle, no run, flighted on off, Gayle gets half-forward and pushes it towards the off-side',
#  'Mosaddek Hossain to Gayle, no run, tossed up on off, Gayle gets well forward in defence',
#  'Mosaddek Hossain to Gayle, wide, Mosaddek slips his first ball down the leg-side, Gayle was looking to sweep and missed, called as a wide',
#  'Rubel to Gayle, 1 run, streaky! On a length and angling across the left-hander, Gayle brought his bat down at an angle, gets an inside edge past the leg-stump',
#  'Rubel to Hetmyer, 1 run, short of a length and just outside off, squirted square on the off-side for a single',
#  'Rubel to Gayle, 1 run, fuller length delivery and slanting across the left-hander, Gayle is late on the drive and gets an edge towards third man',
#  'Rubel to Gayle, no run, on a good length and shaping away from outside off, Gayle has a poke at that and misses',
#  'Rubel to Hetmyer, 1 run, wide full-toss from Rubel, Hetmyer chases and gets a thick edge towards third man',
#  'Rubel to Shai Hope, out Lbw!! That looked close and Gayle asked his partner not to waste a review. First-ball wicket for Rubel, this was full and came back with the angle, Hope went a long way across on the flick and missed. The impact was in front of middle and I reckon it was smashing into the leg-stump - at the worst. West Indies have been rocked twice early. Oh dear! Hawk-Eye says the ball was sliding down with the angle, looked close to the naked eye. Both teams with a DRS error now. Shai Hope lbw b Rubel 6(11)',
#  "Mehidy Hasan to Gayle, no run, lous shout for LBW, but Rahim isn't convinced, might have struck Gayle outside off, he was lunging a fair way forward with both bat/pad close together as he defended, could have an inside edge as well. Replays show it was pad first and the impact is on off, 'three reds' on Hawk-Eye, Gayle gets away",
#  'Mehidy Hasan to Gayle, no run, flighted just outside off, Gayle gets half-forward and pushes it back at the bowler',
#  'Mehidy Hasan to Gayle, SIX, lovely, Gayle breaks the shackles with a monstrous blow, tossed up well outside off, Gayle gets a good stride forward and drills it back past the bowler, watches it saill all the way',
#  'Mehidy Hasan to Gayle, no run, slower and on the stumps, nudged towards the on-side for a single',
#  'Mehidy Hasan to Gayle, no run, nicely flighted outside off and spinning away, drew Gayle forward into the push and beat him on the outside edge',
#  "Mehidy Hasan to Shai Hope, 1 run, tossed up and drifting into Hope's pads, worked away behind square on the on-side. Lots of hesitancy in the running once again, luckily for the two batsmen, the man at backward square leg failed to get to the ball",
#  'Mortaza to Gayle, no run, on a good length and well outside off, pushed towards the off-side',
#  'Mortaza to Gayle, no run, Mashrafe shortens his length outside off, Gayle plays with an open face and defends it towards the off-side',
#  'Mortaza to Gayle, no run, tad fuller and just outside off, Gayle prods forward and defends it towards the off-side',
#  'Mortaza to Shai Hope, 1 run, on a length and on the off-stump line, worked away behind square on the on-side for a single',
#  'Mortaza to Shai Hope, no run, fuller length delivery and well outside off, driven straight to the fielder at point',
#  'Mortaza to Shai Hope, 2 runs, too straight from Mashrafe, clipped away in front of square on the on-side for a couple of runs',
#  'Mehidy Hasan to Shai Hope, 1 run, too full, right under the eyeline of the batter and has been on-driven to long-on for a single',
#  'Mehidy Hasan to Gayle, 1 run, knocked off the back foot into the on-side for a single',
#  'Mehidy Hasan to Shai Hope, 1 run, stays back and has been tucked away off the back foot past mid-wicket for a single',
#  'Mehidy Hasan to Shai Hope, no run, tossed up delivery and has been pushed back to the bowler',
#  'Mehidy Hasan to Shai Hope, no run, flattish ball and has been punched off the back foot, back to the bowler',
#  'Mehidy Hasan to Gayle, 1 run, too full, flighted, driven down to long-off for a single as the dive from the bowler did not help',
#  'Mortaza to Shai Hope, no run, slower delivery outside off and it decks in for the batsman to push the ball away in an awkward manner as he had to account for the movement pretty late in his stance',
#  'Mortaza to Shai Hope, no run, back of a length delivery outside off and has been pushed away into the off-side',
#  'Mortaza to Lewis, out Caught by Mahmudullah!! Did Gayle have to contribute to this dismissal? Might well have been the case. Looks to break the shackles by walking down the track and then slices the heave for the man at mid-off to take it and then tumble down. Mortaza celebrates by fist pumping with his right hand after getting down on one knee. He is thrilled with this for sure. And Bangladesh have got the wicket that they needed. Lewis c Mahmudullah b Mortaza 17(29) [4s-2 6s-1]',
#  'Mortaza to Gayle, 1 run, the top hand comes off the handle thanks to the tennis ball bounce and the lack of pace on that slower delivery. Just a meek punch back past the bowler for the man at mid-off to intercept',
#  'Mortaza to Gayle, no run, another slower delivery cutting across the batsman has been nonchalantly pushed away into the covers',
#  'Mortaza to Gayle, no run, length ball going away from the southpaw and he looks to slog it away but misses. The bowler again delivering a cutter',
#  'Mehidy Hasan to Lewis, no run, almost through the defences of the batsman! That was quick, the ball skidded on after landing on a length and the batsman played back to a delivery to which he should have been forward to. In the end, just manages to get the bat down and push the ball away to point',
#  'Mehidy Hasan to Lewis, no run, goes back and pushes the ball back to the bowler',
#  'Mehidy Hasan to Lewis, no run, paddles the ball away but fails to beat the man at short fine leg as the ball was slanted into the pads',
#  'Mehidy Hasan to Lewis, no run, inside halves the ball coming into him',
#  'Mehidy Hasan to Lewis, no run, slightly pulled back length and has been nurdled away into the on-side',
#  'Mehidy Hasan to Lewis, FOUR, through the hands of the man at extra cover and that is a boundary. That was full and flighted, the batsman drove it away only for the misfield to gift him runs',
#  'Mortaza to Gayle, no run, the slanting across delivery keeps a tad low as the batsman wanted to run it down again. Fails to connect and another dot ball to end the over',
#  'Mortaza to Gayle, no run, back of a length delivery going across and the batsman pushes the ball away to mid-off off the back foot. Wanted a single but then aborted the idea as soon he thought of it',
#  'Mortaza to Gayle, no run, short ball, slaps the cut away but fails to beat the man at cover',
#  'Mortaza to Gayle, no run, looks to turn the ball away on to the on-side and the soft leading edge takes the ball away into the covers',
#  'Mortaza to Gayle, FOUR, works this time does the lack of feet movement. The huge tentacles just open the face of the bat at the time of impact and the ball runs fine past the short third man fielder for a four',
#  "Mortaza to Gayle, no run, slower ball channelling away and the batsman trying to drive it, gets beaten. The cutter moved away and Gayle's cemented feet never could get behind the line of the ball",
#  'Mehidy Hasan to Lewis, no run, fires the arm ball at the sticks and has been barricaded out into the off-side off the back foot',
#  'Mehidy Hasan to Lewis, no run, chops the ball down as the ball landed short. It was turning away and the batsman tapped it out',
#  'Mehidy Hasan to Lewis, no run, floats it up under the eyeline and the batsman thrashes the drive only to find the man at cover point',
#  'Mehidy Hasan to Lewis, no run, quicker and shorter, too wide and left alone for the umpire not to signal it a wide. Tough call as it should have been a wide',
#  'Mehidy Hasan to Lewis, no run, shortish, keeps a bit low and the batsman camping back and trying to cut it, inside edges the ball into the deck',
#  'Mehidy Hasan to Lewis, FOUR, takes it from the sticks and sweeps it convincingly for a four to deep square leg. That was axed away',
#  'Mortaza to Lewis, 1 run, slower delivery from round the wicket and has ben tucked off the back foot to long-on. Lewis wanted a single and gets it as Gayle responded pretty early',
#  'Mortaza to Lewis, no run, length again, at the sticks, pushed out into the off-side',
#  'Mortaza to Lewis, no run, punchy drive off the back foot and the man at cover puts his body on the line to stop it as there was some bad bounce for him to deal with',
#  'Mortaza to Lewis, no run, that was a full ball dished out wide. The batsman freed his arms on that and misses. Slower delivery it was and the batsman pulled the trigger a bit too early',
#  'Mortaza to Lewis, no run, goes round the wicket and goes fuller. Pushed back to the bowler off the full face of the bat',
#  'Mortaza to Gayle, 1 run, length ball and has been pushed away to mid-off for a single. Gayle dealing in singles. That can make headlines',
#  'Mehidy Hasan to Lewis, no run, shortish delivery and the batsman jumps on it but fails to beat the infield. Straight to the man at cover point',
#  'Mehidy Hasan to Lewis, 2 runs, down leg and paddled away. Off the gloves? Might well have been for a brace. Tried hitting it too hard but managed just a speck to send it past the keeper',
#  'Mehidy Hasan to Lewis, no run, opens the face of the bat to a flighted ball outside off. Finds cover point',
#  'Mehidy Hasan to Gayle, 1 run, tries to push it away and the inside edge takes it into the on-side for another quick single',
#  'Mehidy Hasan to Gayle, no run, beaten in flight but adjusts well to keep his balance after charging out and finding out that the length was shortened. He chopped the ball away into the off-side and survived',
#  'Mehidy Hasan to Gayle, no run, pushed away into the off-side as Gayle bent a bit covering the line of the ball',
#  'Mortaza to Lewis, SIX, the journey man has arrived! Sends the ball packing over deep mid. Trifle short and he was on to it in a flash. Picks the length up, swivels on the back foot and then bang. FETCH THAT. Pulled for a maximum',
#  'Mortaza to Lewis, no run, delivery lands just outside off and goes across. The batsman stays his crease and punches it to find the man at cover',
#  'Mortaza to Gayle, 1 run, length ball stays low, Gayle tries to punch it but toe-ends it to mid-off. Before that fielder could charge at the ball, the single was done and dusted. Good alert running from Gayle',
#  'Mortaza to Gayle, no run, length ball, nibbling across the batsman and Gayle plants his front foor forward and defends it into the off-side',
#  'Mortaza to Gayle, no run, open face of the bat meets a length ball and the ball dribbles away to point. So far so good. The bowlers have not given him any room to work with',
#  'Mortaza to Gayle, no run, angles it on to the pads, knocked away into the on-side. That was bowled at 126kph. When will Gayle give the charge?',
#  'Mehidy Hasan to Lewis, no run, flighted outside off and the batsman lunges forward to block it out',
#  'Mehidy Hasan to Lewis, no run, too full, clipped away to mid-on',
#  'Mehidy Hasan to Gayle, 1 run, defintion of miscommunication was penned down there. Both of them were lazying around and a poor throw from the man at short third allows them to make it. Just a push behind square and both were culprit of ball watching. Lewis had to rush through as the throw was at his end',
#  'Mehidy Hasan to Gayle, no run, prods forward and smothers the turn to play it away into the off-side',
#  'Mehidy Hasan to Gayle, no run, on to the pads, Gayle misses the clip',
#  'Mehidy Hasan to Gayle, no run, that was close..to the edge..The ball slants away slightly and the batsman pushing forward, is beaten',
#  'Mortaza to Lewis, no run, full ball angling away and has been driven on the up. This time the man at cover gets around it',
#  'Mortaza to Lewis, no run, length ball and has been punched off the back foot. Slight misfield from the man at covers but that does not yield in any runs',
#  'Mortaza to Lewis, no run, fuller length ball outside off and has been pushed away into the covers',
#  'Mortaza to Lewis, no run, angles into the left-hander, clipped away to square leg',
#  'Mortaza to Gayle, 1 run, drop and run this time! That is nice from the universe boss. More workman like though as he pushed it into the off-side and hared through for a single',
#  "Mortaza to Gayle, no run, starts with a fullish ball on the pads and has been nudged away into the on-side for a single. No, they din't run"]
