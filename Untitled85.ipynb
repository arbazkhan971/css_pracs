# %%
from math import sin 
from math import pi 
from matplotlib import pyplot
from math import exp

# %%
length = 100 
freq = 5 
sequence = [sin(2 * pi * freq * (i/length)) for i in range(length)] # plot sequence 
pyplot.plot(sequence) 
pyplot.show()

# %%
length = 100 
period = 10 
decay = 0.05 
sequence = [0.5 + 0.5 * sin(2 * pi * i / period) * exp(-decay * i) for i in range(length)] 
pyplot.plot(sequence)
pyplot.show()

# %%
length = 50
output = 5
# define model 
model = Sequential() 
model.add(LSTM(20, return_sequences=True, input_shape=(length, 1))) 
model.add(LSTM(20)) 
model.add(Dense(output)) 
model.compile(loss= "mae" , optimizer= "adam" ) 
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 20)            1760
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20)                3280
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 5,145
# Trainable params: 5,145
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from random import randint
from random import uniform
p = randint(10, 20)

# %%
d = uniform(0.01, 0.1)

# %%
d
# Out:
# 0.08687756831358548

# %%
def generate_sequence(length, period, decay): 
    return [0.5 + 0.5 * sin(2 * pi * i / period) * exp(-decay * i) for i in range(length)]

# %%
def generate_examples(length, n_patterns, output): 
    X, y = list(), list() 
    for _ in range(n_patterns): 
        p = randint(10, 20) 
        d = uniform(0.01, 0.1) 
        sequence = generate_sequence(length + output, p, d) 
        X.append(sequence[:-output]) 
        y.append(sequence[-output:]) 
        X = array(X).reshape(n_patterns, length) 
        y = array(y).reshape(n_patterns, output) 
        return X, y

# %%
X, y = generate_examples(20, 5, 5) 
for i in range(len(X)): 
    pyplot.plot([x for x in X[i, :, 0]] + [x for x in y[i]], -o ) 
    pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-c1ac563f2f31> in <module>()
# ----> 1 X, y = generate_examples(20, 5, 5)
#       2 for i in range(len(X)):
#       3     pyplot.plot([x for x in X[i, :, 0]] + [x for x in y[i]], -o )
#       4     pyplot.show()
#
# <ipython-input-24-fa574e392d30> in generate_examples(length, n_patterns, output)
#       7         X.append(sequence[:-output])
#       8         y.append(sequence[-output:])
# ----> 9         X = array(X).reshape(n_patterns, length)
#      10         y = array(y).reshape(n_patterns, output)
#      11         return X, y
#
# ValueError: cannot reshape array of size 20 into shape (5,20)

# %%
from math import sin 
from math import pi 
from math import exp 
from random import random 
from random import randint 
from random import uniform 
from numpy import array 
from matplotlib import pyplot

# %%
from math import sin 
from math import pi 
from math import exp 
from random import random 
from random import randint 
from random import uniform 
from numpy import array 
from matplotlib import pyplot

# generate damped sine wave in [0,1] 
def generate_sequence(length, period, decay): 
    return [0.5 + 0.5 * sin(2 * pi * i / period) * exp(-decay * i) for i in range(length)]

# generate input and output pairs of damped sine waves 
def generate_examples(length, n_patterns, output): 
    X, y = list(), list() 
    for _ in range(n_patterns): 
        p = randint(10, 20) 
        d = uniform(0.01, 0.1) 
        sequence = generate_sequence(length + output, p, d) 
        X.append(sequence[:-output]) 
        y.append(sequence[-output:])

    X = array(X).reshape(n_patterns, length, 1) 
    y = array(y).reshape(n_patterns, output) 
    return X, y
# test problem generation 
X, y = generate_examples(20, 5, 5) 
for i in range(len(X)): 
    pyplot.plot([x for x in X[i, :, 0]] + [x for x in y[i]], "-o" ) 
    pyplot.show()

# %%
# fit model 
X, y = generate_examples(length, 10000, output) 
model.fit(X, y, batch_size=10, epochs=1,verbose=3)
# Out:
# Epoch 1/1

# %%
from keras.models import Sequential 
from keras.layers import LSTM 
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
loss = model.evaluate(X, y, verbose=0) 
print( "MAE: %f" % loss)
# Out:
# MAE: 0.011517

# %%
X, y = generate_examples(length, 1, output) 
yhat = model.predict(X, verbose=0) 
pyplot.plot(y[0], label= y ) 
pyplot.plot(yhat[0], label= "yhat" ) 
pyplot.legend() 
pyplot.show()
