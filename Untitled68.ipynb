# %%
def word_count(words):
    c=0
    for i in words:
       if (len(i)>5 and i[0]==i[-1]):
            c=c+1
    return c
words=["arbaza","mandara","johnnash","sunnya","vinay"]
print(word_count(words))
# Out:
# 1

# %%
num1=int(input("enter a ffirst number"))
num2=int(input("enter second number"))
maxi=num1 if num1>num2 else num2
c=0
for i in range(2,maxi-1):
    if(num1%i and num2%i)==0:
        print(i)
        c=c+1
# Out:
# enter a ffirst number100
# enter second number50
# 2
# 4
# 5
# 10
# 20
# 25
# 50

# %%
engg=list(input().split())
enggs=set(engg)
pro=list(input().split())
pros=set(pro)
mana=list(input().split())
manas=set(mana)

#managers are engineers, but not programmers
set1=(manas & pros) -pros
print(set1)
# Out:
# john jane jonny janice
# jack sam suasane janice
# jane jack susan zack
# sets= set()
# 0

# %%
def sort(tuples):
    return sorted(tuples, key=lambda n:n[-1])
 
a=input("Enter a list of tuples:")
print("Sorted:")
print(sort(a))
# Out:
# Enter a list of tuples:2 3 1 5 6
# Sorted:
# [' ', ' ', ' ', ' ', '1', '2', '3', '5', '6']

# %%
def so(tuples):
    return sorted(tuples,key = lambda n:n[-1])
tuples=input("Enter a list of tuples:")
print("sorted:")
print(so(tuples))
# Out:
# Enter a list of tuples:3 4 5 6 7
# sorted:
# [' ', ' ', ' ', ' ', '3', '4', '5', '6', '7']

# %%
str1=list(input("Enter a First String").split())
str2=list(input("Enter a second String").split())
# Out:
# Enter a First String2 3 4 5 6
# Enter a second String3 4 5 6 7 8

# %%
def match(str1,str2):
    maxi=[]
    diff=[]
    if len(str1)>len(str2):
        maxi=str1
        for i in maxi:
            if i not in str2:
                diff.append(i)
    else:
        maxi=str2
        for i in maxi:
            if i not in str2:
                diff.append(i)
    return diff
str1=list(input("Enter a First String").split())
str2=list(input("Enter a second String").split())
print(match(str1,str2))
# Out:
# Enter a First String2 3 4 5 6 6
# Enter a second String4 5 6
# ['2', '3']

# %%
class py_solution:
    def roman_to_int(self, s):
        rom_val = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
        int_val = 0
        for i in range(len(s)):
            if i > 0 and rom_val[s[i]] > rom_val[s[i - 1]]:
                int_val += rom_val[s[i]] - 2 * rom_val[s[i - 1]]
            else:
                int_val += rom_val[s[i]]
        return int_val

print(py_solution().roman_to_int('MMMCMLXXXVI'))
print(py_solution().roman_to_int('MMMM'))
print(py_solution().roman_to_int('C'))
# Out:
# 3986
# 4000
# 100

# %%
def deci_into_roman(value):
   decimal=[1000,900,500,400,100,90,50,40,10,9,5,4,1]
   roman=["M","CM","D","CD","C","XC","L","XL","X","IX","V","IV","I"]
   i=0
   ans=[]
   while(value>0):
         if(value-decimal[i]>=0):
                ans.append(roman[i])
                value=value-decimal[i]
         else:
            i=i+1
   return("".join(ans))
num=int(input("enter number"))
print(deci_into_roman(num))
# Out:
# enter number7
# VII

# %%
items=[n for n in input().split('-')]
items.sort()
print('-'.join(items))
# Out:
# green-red-black-white
# black-green-red-white

# %%
items=[n for n in input().split('-')]
items.sort()
print("-".join(items))
# Out:
# arb-khan-saleem-aa
# aa-arb-khan-saleem

# %%
def GCD(a,b):
    if b==0:
        return a
    else:
        return GCD(b,a%b)
a=int(input())
b=int(input())
gcd=GCD(a,b)
print("gcd numers ",gcd)
# Out:
# 3
# 27
# gcd numers  3

# %%
file=open("Output.txt","r+")

wordcount={}

for word in file.read().split():
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1
sorted_keys = sorted(wordcount, key=wordcount.get, reverse=True)
for r in sorted_keys:
    print(r, wordcount[r])
# Out:
# the 497
# to 459
# and 270
# it 188
# a 180
# run, 161
# of 135
# on 112
# 1 103
# in 93
# for 93
# his 86
# no 71
# from 60
# length 56
# off, 56
# down 53
# is 53
# with 52
# back 51
# outside 49
# was 48
# up 47
# Chahal 45
# out 44
# he 44
# ball 43
# short 43
# as 43
# Henriques 43
# over 41
# Watson 41
# square 41
# Henriques, 40
# at 37
# Mills 36
# Nehra 35
# away 34
# Choudhary 33
# Rashid 33
# Cutting 32
# this 32
# leg 32
# FOUR, 32
# just 32
# Aniket 31
# Bhuvneshwar 31
# through 31
# Dhawan, 31
# Tymal 30
# one 30
# Yuvraj, 30
# gets 29
# off 29
# full 29
# towards 28
# delivery 28
# into 27
# but 27
# wide 27
# that 26
# Khan 26
# single 25
# bat 24
# Gayle, 24
# The 23
# Aravind 23
# Head, 23
# Gayle 23
# Dhawan 23
# run 22
# Warner 22
# across 22
# Binny 22
# Head 22
# Kedar 22
# Jadhav 22
# good 21
# deep 21
# Jadhav, 21
# Watson, 20
# Mandeep 20
# has 19
# man 19
# Deepak 19
# third 18
# SIX, 17
# A 17
# an 17
# him 17
# mid-wicket 17
# by 17
# goes 17
# 2 17
# ...

# %%
def mean(li):
    m=0
    for i in li:
        m+=i
    return m/len(li)

def var(li):
    var=0
    for i in li:
        var+=(i-mean(li))**2
    return var/len(li)
li=list(map(int,input().split()))
print(mean(li))
print(var(li))
print("sqrt",var**.5)

# %%
file=open("Output.txt","r+")
len3=0
len7=0
for i in file.read().split():
    if len(i)%3==0:
        len3+=1
    if len(i)%7==0:
        len7+=1
print("len 3",len3)
print("len 7",len7)

# %%
a="arbaz"
b=a.split()
print(b)

# %%
#amstrong

num=int(input("enter a number"))
temp=num
sum=0
while temp>0:
    c=temp%10
    sum+=c**3
    temp//10
if num==sum:
    print("number is amstrong")
# Out:
# enter a number340

# %%
class Conversion:
     
    # Constructor to initialize the class variables
    def __init__(self, capacity):
        self.top = -1
        self.capacity = capacity
        self.array = []
        self.output = []
        self.precedence = {'+':1, '-':1, '*':2, '/':2, '^':3}
     
    # check if the stack is empty
    def isEmpty(self):
        return True if self.top == -1 else False
     
    # Return the value of the top of the stack
    def peek(self):
        return self.array[-1]
     
    # Pop the element from the stack
    def pop(self):
        if not self.isEmpty():
            self.top -= 1
            return self.array.pop()
        else:
            return "$"
     
    # Push the element to the stack
    def push(self, op):
        self.top += 1
        self.array.append(op) 
 
    # A utility function to check is the given character
    # is operand 
    def isOperand(self, ch):
        return ch.isalpha()
 
    # Check if the precedence of operator is strictly
    # less than top of stack or not
    def notGreater(self, i):
        try:
            a = self.precedence[i]
            b = self.precedence[self.peek()]
            return True if a  <= b else False
        except KeyError: 
            return False
             
    # The main function that converts given infix expression
    # to postfix expression
    def infixToPostfix(self, exp):
         
        # Iterate over the expression for conversion
        for i in exp:
            # If the character is an operand, 
            # add it to output
            if self.isOperand(i):
                self.output.append(i)
             
            # If the character is an '(', push it to stack
            elif i  == '(':
                self.push(i)
 
            # If the scanned character is an ')', pop and 
            # output from the stack until and '(' is found
            elif i == ')':
                while( (not self.isEmpty()) and self.peek() != '('):
                    a = self.pop()
                    self.output.append(a)
                if (not self.isEmpty() and self.peek() != '('):
                    return -1
                else:
                    self.pop()
 
            # An operat
or is encountered
            else:
                while(not self.isEmpty() and self.notGreater(i)):
                    self.output.append(self.pop())
                self.push(i)
 
        # pop all the operator from the stack
        while not self.isEmpty():
            self.output.append(self.pop())
 
        print "".join(self.output)
 
# Driver program to test above function
exp = "a+b*(c^d-e)^(f+g*h)-i"
obj = Conversion(len(exp))
obj.infixToPostfix(exp)
 
# This code is contributed by Nikhil Kumar Singh(nickzuck_007)
