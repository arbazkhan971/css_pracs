# %%
n=int(input())
def fact(n):
    # Complete this function
    if n>0:
      
      return n*fact(n-1)

    
print("factorial of number",fact(n))
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-236b54aa394a> in <module>()
#       7
#       8
# ----> 9 print("factorial of number",fact(n))
#      10
#      11
#
# <ipython-input-5-236b54aa394a> in fact(n)
#       4     if n>0:
#       5
# ----> 6       return n*fact(n-1)
#       7
#       8
#
# <ipython-input-5-236b54aa394a> in fact(n)
#       4     if n>0:
#       5
# ----> 6       return n*fact(n-1)
#       7
#       8
#
# <ipython-input-5-236b54aa394a> in fact(n)
#       4     if n>0:
#       5
# ----> 6       return n*fact(n-1)
#       7
#       8
#
# <ipython-input-5-236b54aa394a> in fact(n)
#       4     if n>0:
#       5
# ----> 6       return n*fact(n-1)
#       7
#       8
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

# %%
import sys


n = int(input().strip())
def decToBin(n):
    if n==0: return ''
    else:
        return decToBin(n/2) + n%2
b=decToBin(n)

print(b)
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0f24ba233a12> in <module>()
#       7     else:
#       8         return decToBin(n/2) + n%2
# ----> 9 b=decToBin(n)
#      10
#      11 print(b)
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
# ...
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# <ipython-input-20-0f24ba233a12> in decToBin(n)
#       6     if n==0: return ''
#       7     else:
# ----> 8         return decToBin(n/2) + n%2
#       9 b=decToBin(n)
#      10
#
# TypeError: must be str, not float

# %%
n=int(input('please enter the no. in decimal format: '))
x=n
k=[]
while (n>0):
    a=int(float(n%2))
    k.append(a)
    n=(n-a)/2
k.append(0)
string=""
for j in k[::-1]:
    string=string+str(j)
c=0
for i in range(1,len(string)):
       
       if(string[i-1]==string[i]):
                c=c+1

    
       
print(c+1)
# Out:
# please enter the no. in decimal format: 8
# 3
