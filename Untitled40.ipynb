# %%
def qs(a,p,r):
   if(p<r):
      q=partition(a,p,r)
      qs(a,p,q-1)
      qs(a,q+1,r)



def partition(a,p,r):
   x=a[r]
   i=p-1
   for j in range(p,r):
        if(a[j]<=x):
           i=i+1
           t=a[j]
           a[j]=a[i]
           a[i]=t
   t=a[i+1]
   a[i+1]=a[r]
   a[r]=t
   print(a)
   return i+1




#merging
def mergeSort(a):

    if len(a)>1:
        mid = len(a)//2
        lefthalf = a[:mid]
        righthalf = a[mid:]

        mergeSort(lefthalf)
        mergeSort(righthalf)
##merging
        i=0
        j=0
        k=0
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                a[k]=lefthalf[i]
                i=i+1
            else:
                a[k]=righthalf[j]
                j=j+1
            k=k+1

        while i < len(lefthalf):
            a[k]=lefthalf[i]
            i=i+1
            k=k+1
            print(l)

        while j < len(righthalf):
            a[k]=righthalf[j]
            j=j+1
            k=k+1
            print(l)



print ('1: mergesort: ')
print ('2: quick sort: ')
print
('3: Exit \n')

c = int(input())

while (1 <= c <= 2):
    if (c == 1):
        print ('Enter number of elements')
        n = int(input())
        l = []
        print('Enter elements: '),
        for i in range(n):
            s = int(input())
            l.append(s)
        mergeSort(l)
        print(l)

    elif (c == 2):
        print('Enter number of elements: ')
        r = int(input())
        a = []
        print('Enter elements')
        for i in range(r):
            s = int(input())
            a.append(s)
        print(a)
        r = r - 1
        p = 0
        qs(a,0,r)

    else:
        print('Exit')


    print('1: mergesort: ')
    print('2: quick sort: ')
    print('3: Exit \n')

    c = int(input())
    '''    
1: mergesort: 
2: quick sort: 
1
Enter number of elements
8
Enter elements: 
22
44
21
76
46
43
55
41
[22, 44, 21, 76, 46, 43, 55, 41]
[22, 44, 21, 76, 46, 43, 55, 41]
[22, 44, 21, 76, 46, 43, 55, 41]
[22, 44, 21, 76, 46, 43, 55, 41]
[22, 44, 21, 76, 46, 43, 55, 41]
[22, 44, 21, 76, 46, 43, 55, 41]
[21, 22, 41, 43, 44, 46, 55, 76]
[21, 22, 41, 43, 44, 46, 55, 76]
1: mergesort: 
2: quick sort: 
3: Exit 

2
Enter number of elements: 
8
Enter elements
33
44
3
22
3
87
65
33
[33, 44, 3, 22, 3, 87, 65, 33]
[33, 3, 22, 3, 33, 87, 65, 44]
[3, 3, 22, 33, 33, 87, 65, 44]
[3, 3, 22, 33, 33, 87, 65, 44]
[3, 3, 22, 33, 33, 44, 65, 87]
[3, 3, 22, 33, 33, 44, 65, 87]
1: mergesort: 
2: quick sort: 
3: Exit 
    
    
    '''
# Out:
# 1: mergesort:
# 2: quick sort:
# 1
# Enter number of elements
# 8
# Enter elements:
# 22
# 44
# 21
# 76
# 46
# 43
# 55
# 41
# [22, 44, 21, 76, 46, 43, 55, 41]
# [22, 44, 21, 76, 46, 43, 55, 41]
# [22, 44, 21, 76, 46, 43, 55, 41]
# [22, 44, 21, 76, 46, 43, 55, 41]
# [22, 44, 21, 76, 46, 43, 55, 41]
# [22, 44, 21, 76, 46, 43, 55, 41]
# [21, 22, 41, 43, 44, 46, 55, 76]
# [21, 22, 41, 43, 44, 46, 55, 76]
# 1: mergesort:
# 2: quick sort:
# 3: Exit
#
# 2
# Enter number of elements:
# 8
# Enter elements
# 33
# 44
# 3
# 22
# 3
# 87
# 65
# 33
# [33, 44, 3, 22, 3, 87, 65, 33]
# [33, 3, 22, 3, 33, 87, 65, 44]
# [3, 3, 22, 33, 33, 87, 65, 44]
# [3, 3, 22, 33, 33, 87, 65, 44]
# [3, 3, 22, 33, 33, 44, 65, 87]
# [3, 3, 22, 33, 33, 44, 65, 87]
# 1: mergesort:
# 2: quick sort:
# 3: Exit

# %%
def qs(a,p,r):
   if(p<r):
      q=partition(a,p,r)
      qs(a,p,q-1)
      qs(a,q+1,r)



def partition(a,p,r):
   x=a[r]
   i=p-1
   for j in range(p,r):
        if(a[j]<=x):
           i=i+1
           t=a[j]
           a[j]=a[i]
           a[i]=t
   t=a[i+1]
   a[i+1]=a[r]
   a[r]=t
   print(a)
   return i+1




#merging
def mergeSort(a):

    if len(a)>1:
        mid = len(a)//2
        lefthalf = a[:mid]
        righthalf = a[mid:]

        mergeSort(lefthalf)
        mergeSort(righthalf)
##merging
        i=0
        j=0
        k=0
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                a[k]=lefthalf[i]
                i=i+1
            else:
                a[k]=righthalf[j]
                j=j+1
            k=k+1

        while i < len(lefthalf):
            a[k]=lefthalf[i]
            i=i+1
            k=k+1
            print(l)

        while j < len(righthalf):
            a[k]=righthalf[j]
            j=j+1
            k=k+1
            print(l)



print ('1: mergesort: ')
print ('2: quick sort: ')
print
('3: Exit \n')

c = int(input())

while (1 <= c <= 2):
    if (c == 1):
        print ('Enter number of elements')
        n = int(input())
        l = []
        print('Enter elements: '),
        for i in range(n):
            s = int(input())
            l.append(s)
        mergeSort(l)
        print(l)

    elif (c == 2):
        print('Enter number of elements: ')
        r = int(input())
        a = []
        print('Enter elements')
        for i in range(r):
            s = int(input())
            a.append(s)
        print(a)
        r = r - 1
        p = 0
        qs(a,0,r)

    else:
        print('Exit')


    print('1: mergesort: ')
    print('2: quick sort: ')
    print('3: Exit \n')

    c = int(input())
