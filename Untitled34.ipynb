# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 22 18:12:17 2018

@author: arbaz
"""
import sys
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
d=0    
while(True):
 print("1.Insertion_sort \n 2.selection_sort\n 3.exit")
 c=int(input())
 if(c==1):
    insertionsort(arr)
 elif(c==2):
    selectionsort(arr)
 elif(c==3):
    sys.exit()

def selectionsort(newarr):
    print("You selected selection sort. \n") 

    print("Before sorting the array is", newarr) 
    for i in range(0,len(newarr)-1): 
        m=i 
        for j in range(i+1,len(newarr)):
            if(newarr[j]<newarr[m]): 
                m=j 
        temp = newarr[i]
        newarr[i]=newarr[m]
        newarr[m]=temp
    print("After sorting the array is", newarr) 
def insertionsort(newarr):  
    print("You selected insertion sort. \n")

    print("Before sorting the array is", newarr) 
    print( "After sorting the array is", insertion(newarr))
def insertion(iarr):
    for i in range(1,len(iarr)):
        value = iarr[i]
        j=i-1
        while (j>=0) and (iarr[j]>value):
            iarr[j+1] = iarr[j] 
            j=j-1
            iarr[j+1] = value 
    return iarr

# %%
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =input("num :")
     arr.append(int(n))
selection_sort(arr)
print(arr)
# Out:
# enter a numbers of elements of array5
# 5
# enter a number of array
# num :1
# num :2
# num :3
# num :4
# num :5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-318f07c2e6b2> in <module>()
#       6      n =input("num :")
#       7      arr.append(int(n))
# ----> 8 selection_sort(arr)
#       9 print(arr)
#
# <ipython-input-7-49e280c4a8bd> in selection_sort(arr)
#       1 def selection_sort(arr):
# ----> 2     for i in range(len(arr-1)):
#       3         index=i
#       4         for j in range(i+1,len(arr),1):
#       5             if(arr[j]<arr[index]):
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
print("enter your choice\n")
print("1. insertion sort \n selection sort")
c=int(input())


while()
selection_sort(arr)
print(arr)


def selection_sort(arr):
   for i in range(len(arr)-1,0,-1):
       maxpos=0
       for j in range(1,i+1):
           if arr[j]>arr[maxpos]:
               maxpos = i

       temp = arr[i]
       arr[i] = arr[j]
       arr[j] = temp

# %%
def main():
    print  '''Help Menu :
            1. Bubble Sort,
            2. Selection Sort,
            3. Merge Sort,
            4. Quick Sort,
            5. Insertion Sort'''
    num=raw_input("Which sorting algo would you like to run?");
    options = {'1' : bubblesort,
           '2' : selectionsort,
           '3' : mergesort,
           '4' : quicksort,
           '5' : insertionsort,
   } #Declaring a dictionary
    options.get(num, errorMessage)()


if __name__ == '__main__':
    main()

# %%
def selection_sort(arr):
   for i in range(len(arr)-1,0,-1):
       maxpos=0
       for j in range(1,i+1):
           if arr[j]>arr[maxpos]:
               maxpos = i

       temp = arr[i]
       arr[i] = arr[j]
       arr[j] = temp

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 22 18:12:17 2018

@author: arbaz
"""
import sys
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
d=0    
while(True):
 print("1.Insertion_sort \n 2.selection_sort\n 3.exit")
 c=int(input())
 if(c==1):
    insertionsort(arr)
 elif(c==2):
    selectionsort(arr)
 elif(c==3):
    sys.exit()

def selectionsort(newarr):
    print("You selected selection sort. \n") 

    print("Before sorting the array is", newarr) 
    for i in range(0,len(newarr)-1): 
        m=i 
        for j in range(i+1,len(newarr)):
            if(newarr[j]<newarr[m]): 
                m=j 
        temp = newarr[i]
        newarr[i]=newarr[m]
        newarr[m]=temp
    print("After sorting the array is", newarr) 
def insertionsort(newarr):  
    print("You selected insertion sort. \n")

    print("Before sorting the array is", newarr) 
    print( "After sorting the array is", insertion(newarr))
def insertion(iarr):
    for i in range(1,len(iarr)):
        value = iarr[i]
        j=i-1
        while (j>=0) and (iarr[j]>value):
            iarr[j+1] = iarr[j] 
            j=j-1
            iarr[j+1] = value 
    return iarr

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 22 18:12:17 2018

@author: arbaz
"""
import sys
arr=[]
a=int(input("enter a numbers of elements of array"))
print(a)
print("enter a number of array")
for i in range(a):
     n =int(input())
     arr.append(n)
    

 

def selectionsort(newarr):
    print("You selected selection sort. \n") 

    print("Before sorting the array is", newarr) 
    for i in range(0,len(newarr)-1): 
        m=i 
        for j in range(i+1,len(newarr)):
            if(newarr[j]<newarr[m]): 
                m=j 
        temp = newarr[i]
        newarr[i]=newarr[m]
        newarr[m]=temp
    print("After sorting the array is", newarr) 

def insertionsort(newarr):  
    print("You selected insertion sort. \n")

    print("Before sorting the array is", newarr) 
    print( "After sorting the array is", insertion(newarr))

def insertion(iarr):
    for i in range(1,len(iarr)):
        value = iarr[i]
        j=i-1
        while (j>=0) and (iarr[j]>value):
            iarr[j+1] = iarr[j] 
            j=j-1
            iarr[j+1] = value 
    return iarr
while(True):
 print("1.Insertion_sort \n 2.selection_sort\n3.exit")
 c=int(input())
 
 if(c==1):
   insertionsort(arr)
 elif(c==2):
   selectionsort(arr)
 elif(c==3):
   sys.exit()
