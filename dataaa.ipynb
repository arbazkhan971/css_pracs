# %%
import numpy as np

# %%
import pandas as pd

# %%
label=['a','b','c']

# %%
my_array=[1,2,3]

# %%
arr=np.array(my_array)

# %%
d={'a':1,'b':2,'c':3}

# %%
ser2=pd.Series(my_array,label)

# %%
pd.Series(d)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
label
# Out:
# ['a', 'b', 'c']

# %%
ser=pd.Series([1,2,3,4],['a','b','c','d'])

# %%
ser['a']
# Out:
# 1

# %%
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser/ser2
# Out:
# a    1.0
# b    1.0
# c    1.0
# d    NaN
# dtype: float64

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df= pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['new']=df['W']+df['Y']

# %%
df=df.drop('new',1)

# %%
df.iloc[3]
# Out:
# W      0.188695
# X     -0.758872
# Y     -0.933237
# Z      0.955057
# new   -0.744542
# Name: D, dtype: float64

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
booldf= df >0

# %%
booldf
# Out:
#        W      X      Y      Z    new
# A   True   True   True   True   True
# B   True  False  False   True  False
# C  False   True   True  False  False
# D   True  False  False   True  False
# E   True   True   True   True   True

# %%
df['W']>0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
res=df[df['W']>0][['Y','X']]

# %%
res
# Out:
#           Y         X
# A  0.907969  0.628133
# B -0.848077 -0.319318
# D -0.933237 -0.758872
# E  2.605967  1.978757

# %%
df[(df['W']>0) | (df['Y']>1)]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df.reset_index(newind)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-ca5833c2b381> in <module>()
# ----> 1 df.reset_index(newind)
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in reset_index(self, level, drop, inplace, col_level, col_fill)
#    2918             if not isinstance(level, (tuple, list)):
#    2919                 level = [level]
# -> 2920             level = [self.index._get_level_number(lev) for lev in level]
#    2921             if isinstance(self.index, MultiIndex):
#    2922                 if len(level) < self.index.nlevels:
#
# C:\annn\lib\site-packages\pandas\core\indexes\base.pyc in _get_level_number(self, level)
#    1561
#    1562     def _get_level_number(self, level):
# -> 1563         self._validate_index_level(level)
#    1564         return 0
#    1565
#
# ...

# %%
newind= 'CA NY WY CO MO'.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'CO']

# %%
df['STATES'] = newind

# %%
df
# Out:
#           W         X         Y         Z STATES
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     CO
# E  0.190794  1.978757  2.605967  0.683509     MO

# %%
df.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-92247dbf2b8a> in <module>()
# ----> 1 df.set_index('index')
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2828                 names.append(None)
#    2829             else:
# -> 2830                 level = frame[col]._values
#    2831                 names.append(col)
#    2832                 if drop:
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# ...

# %%
outside = ['G1','G1', 'G1','G2','G2','G2']
inside =[1,2,3,1,2,3]
hier_index=list(zip(outside,inside))
heir_index=pd.MultiIndex.from_tuples(hier_index)

# %%
outside
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
inside
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df=pd.DataFrame(randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#                 A         B
# (G1, 1)  0.302665  1.693723
# (G1, 2) -1.706086 -1.159119
# (G1, 3) -0.134841  0.390528
# (G2, 1)  0.166905  0.184502
# (G2, 2)  0.807706  0.072960
# (G2, 3)  0.638787  0.329646

# %%
df['G1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-edb78285e60a> in <module>()
# ----> 1 df['G1']
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\annn\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\annn\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
# ...

# %%
df.index.name=['groups','num']

# %%
df
# Out:
#                       A         B
# [groups, num]
# (G1, 1)        0.302665  1.693723
# (G1, 2)       -1.706086 -1.159119
# (G1, 3)       -0.134841  0.390528
# (G2, 1)        0.166905  0.184502
# (G2, 2)        0.807706  0.072960
# (G2, 3)        0.638787  0.329646

# %%
df.xs(1,level='num')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-ccb55344f449> in <module>()
# ----> 1 df.xs(1,level='num')
#
# C:\annn\lib\site-packages\pandas\core\generic.pyc in xs(self, key, axis, level, drop_level)
#    2008         labels = self._get_axis(axis)
#    2009         if level is not None:
# -> 2010             loc, new_ax = labels.get_loc_level(key, level=level,
#    2011                                                drop_level=drop_level)
#    2012
#
# AttributeError: 'Index' object has no attribute 'get_loc_level'

# %%
d = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df=pd.DataFrame(d)

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
# Out:
#   File "<ipython-input-110-76d5a86e25c7>", line 1
#     df[].fillna(value=df.mean())
#        ^
# SyntaxError: invalid syntax

# %%
data={'company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
     'person':['sam','charlie','amy','vanessa','car','sarah'],
       'sales':[200,120,340,124,243,350]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   company   person  sales
# 0    GOOG      sam    200
# 1    GOOG  charlie    120
# 2    MSFT      amy    340
# 3    MSFT  vanessa    124
# 4      FB      car    243
# 5      FB    sarah    350

# %%
bycomp =df.groupby('company')

# %%
bycomp.sum().loc['FB']
# Out:
# sales    593
# Name: FB, dtype: int64

# %%
df.groupby('company').describe().transpose()['FB']
# Out:
# sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# Name: FB, dtype: float64

# %%
D1={'A':['A0','A1','A2','A3'],
      'B':['B0','B1','B2','B3']
   ,'C':['C0','C1','C2','C3']
   ,'D':['D0','D1','D2','D3']}

D2={'A':['A4','A5','A6','A7'],
      'B':['B4','B5','B6','B7']
   ,'C':['C4','C5','C6','C7']
   ,'D':['D4','D5','D6','D7']}
D3={'A':['A8','A9','A10','A11'],
      'B':['B8','B9','B10','B11']
   ,'C':['C8','C9','C10','C11']
   ,'D':['D8','D9','D10','D11']}

# %%
df1=pd.DataFrame(D1,index=[0,1,2,3])
df2=pd.DataFrame(D2,index=[4,5,6,7])
df3=pd.DataFrame(D3,index=[8,9,10,11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df=pd.DataFrame({'col1':[1,2,3,4],
                  'col2':[444,555,666,444],
               'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[df[()'col1']>2 & ]
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return 2*x

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col3'].apply(lambda x: x*3)
# Out:
# 0    abcabcabc
# 1    defdefdef
# 2    ghighighi
# 3    xyzxyzxyz
# Name: col3, dtype: object

# %%
df.drop('col1',axis=1)
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# Out:
# Index([u'col1', u'col2', u'col3'], dtype='object')

# %%
df.sort_values('col3')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
pwd
# Out:
# u'C:\\Users\\arbaz'

# %%
df=pd.read_csv('FL_insurance_sample.csv')

# %%
df.to_csv('My_output')

# %%
pd.read_csv('My_output')
# Out:
#        Unnamed: 0  policyID statecode           county  eq_site_limit  \
# 0               0    119736        FL      CLAY COUNTY       498960.0
# 1               1    448094        FL      CLAY COUNTY      1322376.3
# 2               2    206893        FL      CLAY COUNTY       190724.4
# 3               3    333743        FL      CLAY COUNTY            0.0
# 4               4    172534        FL      CLAY COUNTY            0.0
# 5               5    785275        FL      CLAY COUNTY            0.0
# 6               6    995932        FL      CLAY COUNTY            0.0
# 7               7    223488        FL      CLAY COUNTY       328500.0
# 8               8    433512        FL      CLAY COUNTY       315000.0
# 9               9    142071        FL      CLAY COUNTY       705600.0
# 10             10    253816        FL      CLAY COUNTY       831498.3
# 11             11    894922        FL      CLAY COUNTY            0.0
# ...

# %%
data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
data
# Out:
# [                                             Bank Name                City  \
#  0      The Farmers and Merchants State Bank of Argonia             Argonia
#  1                                  Fayette County Bank          Saint Elmo
#  2    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  3                                       First NBC Bank         New Orleans
#  4                                        Proficio Bank  Cottonwood Heights
#  5                        Seaway Bank and Trust Company             Chicago
#  6                               Harvest Community Bank          Pennsville
#  7                                          Allied Bank            Mulberry
#  8                         The Woodbury Banking Company            Woodbury
#  9                               First CornerStone Bank     King of Prussia
#  10                                  Trust Company Bank             Memphis
# ...

# %%
type(data)
# Out:
# list

# %%
data[0].head()
# Out:
#                                            Bank Name                City  ST  \
# 0    The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 1                                Fayette County Bank          Saint Elmo  IL
# 2  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 3                                     First NBC Bank         New Orleans  LA
# 4                                      Proficio Bank  Cottonwood Heights  UT
#
#     CERT                Acquiring Institution      Closing Date  \
# 0  17719                          Conway Bank  October 13, 2017
# 1   1802            United Fidelity Bank, fsb      May 26, 2017
# 2  30003  First-Citizens Bank & Trust Company       May 5, 2017
# 3  58302                         Whitney Bank    April 28, 2017
# 4  35495                    Cache Valley Bank     March 3, 2017
#
#        Updated Date
# 0  October 20, 2017
# 1     July 26, 2017
# 2     July 26, 2017
# 3     July 26, 2017
# ...

# %%
import pandas as pd

# %%
sal= pd.read_csv('Salaries.csv')
# Out:
# C:\annn\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184      NaN  567595.43         567595.43  2011
# 1  155966      245132   137811      NaN  538909.28         538909.28  2011
# 2  212739      106088  16452.6      NaN  335279.91         335279.91  2011
# 3   77916     56120.7   198307      NaN  332343.61         332343.61  2011
# 4  134402        9737   182235      NaN  326373.19         326373.19  2011
#
#    Notes         Agency Status
# 0    NaN  San Francisco    NaN
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148049 non-null object
# OvertimePay         148654 non-null object
# OtherPay            148654 non-null object
# Benefits            112495 non-null object
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
sal['TotalPayBenefits'].max()
# Out:
# 567595.43000000005

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle BasePay OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140547     97868.8
#
#    OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 24  31909.3      NaN  270324.91         270324.91  2011    NaN  San Francisco
#
#    Status
# 24    NaN

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
plt.plot(x,y,'-r')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
# Out:
# Text(0.5,1,u'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#OO

fig =plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('title')
# Out:
# Text(0.5,1,u'title')

# %%
fig =plt.figure()
axes1 =fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.1,0.5,0.3,0.4])
axes1.plot(x,y,'b')
axes2.plot(y,x,'r')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2) 
axes[0].plot(x,y,'r')
axes[0].set_xlabel('X axis')
axes[0].set_ylabel('Y axis')
axes[0].set_title('title')
axes[1].plot(y,x,'y')
axes[1].set_xlabel('X axis')
axes[1].set_ylabel('Y axis')
axes[1].set_title('title')
plt.tight_layout()

# %%
fig,axes =plt.subplots(nrows=2 ,ncols=1,figsize=(8,2))


axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig = plt.figure()

ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='x square is there')
ax.plot(x,x**3 ,label='x is cubed')
ax.legend(loc=0)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet',lw=2,ls='--')
ax.set_xlim([0,1])
ax.set_ylim([0,3])
# Out:
# (0, 3)

# %%
import  numpy as np
x=np.linspace(0,100)
y=x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_title('Title')
# Out:
# Text(0.5,1,u'Title')

# %%
fig =plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.4,.4])
axes1.plot(x,z)
axes1.set_xlabel('X label')
axes1.set_ylabel('Y label')
axes1.set_title('Title')
axes2.plot(x,y)
axes2.set_xlabel('X label')
axes2.set_ylabel('Y label')
axes2.set_title('Zoom')
axes2.set_xlim([20,22])
axes2.set_ylim([30,50])
# Out:
# (30, 50)

# %%
fig,axes=plt.subplots(1,2)

axes[0].plot(x,y,ls='--',lw=3)
axes[1].plot(x,z,'r',lw=3)

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips =sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=300)

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=10)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
import seaborn as sns
# %matplotlib inline
tip=sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.mean)

# %%
import numpy as np

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
# Out:
# C:\annn\lib\site-packages\seaborn\categorical.py:2567: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='count')

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')
tips.head()
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tc=tips.corr()

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp,cmap='coolwarm',linecolor='black',linewidths='2')

# %%
sns.clustermap(fp,cmap='coolwarm',linecolor='black',linewidths=2)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect=.6,size=8)

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
g= sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-34417b7dda50> in <module>()
#       1 g= sns.PairGrid(iris)
#       2 g.map_diag(sns.distplot)
# ----> 3 g.map_upper(plt.scatter)
#       4 g.map_lower(sns.kdeplot)
#
# NameError: name 'plt' is not defined

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
import matplotlib.pyplot as plt

g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower( sns.kdeplot)

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map ( plt.scatter,'total_bill','tip')

# %%
sns.countplot(x='sex',da
# Out:
#   File "<ipython-input-180-ad537613f8c5>", line 3
#     sns.countplot(x='sex',da
#                             ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.distplot(titanic['fare'],kde=False,color='red',bins=61)

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
sns.countplot(x='sex',data=titanic)

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title()

# %%
g=sns.FacetGrid(data=titanic,col='sex',)
g.map(sns.distplot,'age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-a1934ea95183> in <module>()
# ----> 1 g=sns.FacetGrid(data=titanic,col='sex',kde=False)
#       2 g.map(sns.distplot,'age')
#
# TypeError: __init__() got an unexpected keyword argument 'kde'

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df1=pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3=pd.read_csv('df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=0.5)

# %%
df2.plot.bar(alpha=.5)
plt.legend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-212-ca39932da29c> in <module>()
#       1 df2.plot.bar(alpha=.5)
# ----> 2 plt.legend(4)
#
# C:\annn\lib\site-packages\matplotlib\pyplot.pyc in legend(*args, **kwargs)
#    3721 @docstring.copy_dedent(Axes.legend)
#    3722 def legend(*args, **kwargs):
# -> 3723     ret = gca().legend(*args, **kwargs)
#    3724     return ret
#    3725
#
# C:\annn\lib\site-packages\matplotlib\axes\_axes.pyc in legend(self, *args, **kwargs)
#     553             # Get as many handles as there are labels.
#     554             handles = [handle for handle, label
# --> 555                        in zip(self._get_legend_handles(handlers), labels)]
#     556
#     557         # Two arguments:
#
# TypeError: izip argument #2 must support iteration

# %%
df1.plot.line(x=df1.index,y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-225-3e0001d12a6f> in <module>()
# ----> 1 df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coo')
#
# C:\annn\lib\site-packages\pandas\plotting\_core.pyc in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwds)
#    2834         if gridsize is not None:
#    2835             kwds['gridsize'] = gridsize
# -> 2836         return self(kind='hexbin', x=x, y=y, C=C, **kwds)
#
# C:\annn\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
df2['a'].plot.density()
